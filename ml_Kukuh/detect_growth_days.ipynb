# %% [markdown]
# **IMPORT**

# %%
import os
import pandas as pd
import tensorflow as tf

# %%
def normalize_series(data, min, max):
    data-=min
    data/=max
    return data

def windowed_dataset(series, batch_size, n_past=24, n_future=4, shift=1):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(size=n_past+n_future, shift=shift, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(n_past+n_future))
    ds = ds.shuffle(1000)
    ds = ds.map(lambda w: (w[:-n_future], w[-n_future:, :1]))
    ds = ds.batch(batch_size).prefetch(shift)
    return ds

# %%
# Retrieve dataset
df = pd.read_csv(os.path.join('lettuce_growth_days', 'lettuce_dataset.csv'), sep=',', encoding='ISO-8859-1')

# Delete column date, plant_id
df = df.drop(columns=['Plant_ID', 'Date'])

# Number of features in dataset
N_FEATURES = df.shape[1]

print(df.head())
print(F'n features: {N_FEATURES}')

# Normalize data
data = df.values
split_time = int(len(data)*0.8)
data = normalize_series(data, data.min(axis=0), data.max(axis=0))

x_train = data[:split_time]
print(f'Train: {len(x_train)}')
x_valid = data[split_time:]
print(f'Test: {len(x_valid)}')

# DO NOT CHANGE THIS
BATCH_SIZE = 32
N_PAST = 24  # Number of past time steps based on which future observations should be predicted
N_FUTURE = 24  # Number of future time steps which are to be predicted.
SHIFT = 1  # By how many positions the window slides to create a new window of observations.

# Code to create windowed train and validation datasets.
# Complete the code in windowed_dataset.
# YOUR CODE HERE
train_set = windowed_dataset(series=x_train, batch_size=BATCH_SIZE, n_past=N_PAST, n_future=N_FUTURE, shift=SHIFT)
# YOUR CODE HERE
valid_set = windowed_dataset(series=x_valid, batch_size=BATCH_SIZE, n_past=N_PAST, n_future=N_FUTURE, shift=SHIFT)

model = tf.keras.models.Sequential([
    # tf.keras.layers.LSTM(64, 'relu', return_sequences=True, input_shape=[N_PAST, N_FEATURES]),
    tf.keras.layers.Dense(64, input_shape=(N_PAST, N_FEATURES)),
    tf.keras.layers.Dense(32),
    tf.keras.layers.Dense(N_FUTURE, 'linear'),
])


class StopWhenReachDesireMAE(tf.keras.callbacks.Callback):
    def __init__(self, monitor='mae', monitor2='val_mae', target=0.14):
        super(StopWhenReachDesireMAE, self).__init__()
        self.monitor = monitor
        self.monitor2 = monitor2
        self.target = target

    def on_epoch_end(self, epoch, logs=None):
        current = logs.get(self.monitor)
        current2 = logs.get(self.monitor2)
        if current is not None and current2 is not None:
            if current < self.target and current2 < self.target:
                print(
                    f'\nEpoch {epoch + 1}: {self.monitor} and {self.monitor2} have reached {self.target}. Stopping training.')
                self.model.stop_training = True

stop_callback = StopWhenReachDesireMAE('mae', 'val_mae', 0.05)

# Code to train and compile the model
# YOUR CODE HERE
model.compile(
    loss='mae',
    optimizer='adam',
    metrics=['mae']
)

model.fit(
    train_set,
    epochs=60,
    validation_data=valid_set,
    callbacks=[stop_callback]
)

# # Evaluate the model
# loss, mae = model.evaluate(X_test, y_test)
# print(f'Mean Absolute Error on test data: {mae}')
# 
# # Make predictions
# y_pred = model.predict(X_test)
# 
# # Optional: Convert predictions and actual values to a more readable format
# results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred.flatten()})
# print(results.head())
# Out:
#    Temperature (°C)  Humidity (%)  TDS Value (ppm)  pH Level  Growth Days
# 0              33.4            53              582       6.4            1
# 1              33.5            53              451       6.1            2
# 2              33.4            59              678       6.4            3
# 3              33.4            68              420       6.4            4
# 4              33.4            74              637       6.5            5
# n features: 5
# Train: 2535
# Test: 634
# D:\Studi\MBKM\capstone\Capstone_Model_NPK\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0
60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0500 - mae: 0.0500 - val_loss: 0.2418 - val_mae: 0.2418
# Epoch 34/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0495 - mae: 0.0495 - val_loss: 0.2463 - val_mae: 0.2463
# Epoch 35/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0492 - mae: 0.0492 - val_loss: 0.2376 - val_mae: 0.2376
# Epoch 36/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0500 - mae: 0.0500 - val_loss: 0.2415 - val_mae: 0.2415
# Epoch 37/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mae: 0.0492 - val_loss: 0.2406 - val_mae: 0.2406
# Epoch 38/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0496 - mae: 0.0496 - val_loss: 0.2416 - val_mae: 0.2416
# Epoch 39/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mae: 0.0492 - val_loss: 0.2444 - val_mae: 0.2444
# Epoch 40/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0495 - mae: 0.0495 - val_loss: 0.2394 - val_mae: 0.2394
# Epoch 41/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0500 - mae: 0.0500 - val_loss: 0.2500 - val_mae: 0.2500
# Epoch 42/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0489 - mae: 0.0489 - val_loss: 0.2470 - val_mae: 0.2470
# Epoch 43/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0495 - mae: 0.0495 - val_loss: 0.2376 - val_mae: 0.2376
# Epoch 44/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0491 - mae: 0.0491 - val_loss: 0.2431 - val_mae: 0.2431
# Epoch 45/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mae: 0.0490 - val_loss: 0.2483 - val_mae: 0.2483
# Epoch 46/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0487 - mae: 0.0487 - val_loss: 0.2464 - val_mae: 0.2464
# Epoch 47/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0491 - mae: 0.0491 - val_loss: 0.2467 - val_mae: 0.2467
# Epoch 48/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0488 - mae: 0.0488 - val_loss: 0.2464 - val_mae: 0.2464
# Epoch 49/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0491 - mae: 0.0491 - val_loss: 0.2497 - val_mae: 0.2497
# Epoch 50/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0489 - mae: 0.0489 - val_loss: 0.2513 - val_mae: 0.2513
# Epoch 51/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0486 - mae: 0.0486 - val_loss: 0.2440 - val_mae: 0.2440
# Epoch 52/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0494 - mae: 0.0494 - val_loss: 0.2519 - val_mae: 0.2519
# Epoch 53/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0490 - mae: 0.0490 - val_loss: 0.2500 - val_mae: 0.2500
# Epoch 54/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0490 - mae: 0.0490 - val_loss: 0.2501 - val_mae: 0.2501
# Epoch 55/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0487 - mae: 0.0487 - val_loss: 0.2494 - val_mae: 0.2494
# Epoch 56/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0491 - mae: 0.0491 - val_loss: 0.2520 - val_mae: 0.2520
# Epoch 57/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0489 - mae: 0.0489 - val_loss: 0.2483 - val_mae: 0.2483
# Epoch 58/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mae: 0.0487 - val_loss: 0.2503 - val_mae: 0.2503
# Epoch 59/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0489 - mae: 0.0489 - val_loss: 0.2474 - val_mae: 0.2474
# Epoch 60/60
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0495 - mae: 0.0495 - val_loss: 0.2597 - val_mae: 0.2597

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# Load the data
data = pd.read_csv(os.path.join('lettuce_growth_days', 'lettuce_dataset.csv'), sep=',', encoding='ISO-8859-1')

# Convert 'Date' to numerical values if necessary
data['Date'] = pd.to_datetime(data['Date']).map(pd.Timestamp.toordinal)

# Normalize the input features
features = ['Date', 'Temperature (°C)', 'TDS Value (ppm)', 'pH Level']
target = 'Growth Days'

X = data[features]
y = data[target]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

class CustomCallback(tf.keras.callbacks.Callback):
    def __init__(self, monitor='mae', monitor1='val_mae', target=0.1):
        super(CustomCallback, self).__init__()
        self.monitor = monitor
        self.monitor1 = monitor1
        self.target = target
        
    def on_epoch_end(self, epoch, logs=None):
        if logs[self.monitor] is not None and logs[self.monitor1] is not None:
            if logs[self.monitor] < self.target and logs[self.monitor1] < self.target:
                print(f'\n{self.monitor}: {logs[self.monitor]} < {self.target}')
                print(f'\n{self.monitor1}: {logs[self.monitor1]} < {self.target}')
                self.model.stop_training = True

# Build the model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1, activation='linear')  # Linear activation for regression
])

# Compile the model
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

cust_callbacks = CustomCallback(monitor='mae', target=0.045)
# Train the model
history = model.fit(X_train, y_train, epochs=1000, validation_split=0.2, batch_size=32, callbacks=[cust_callbacks])

# Evaluate the model
loss, mae = model.evaluate(X_test, y_test)
print(f'Mean Absolute Error on test data: {mae}')

# Make predictions
y_pred = model.predict(X_test)

# Optional: Convert predictions and actual values to a more readable format
results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred.flatten()})
print(results.head())
# Out:
# Epoch 1/1000
# D:\Studi\MBKM\capstone\Capstone_Model_NPK\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 717.4463 - mae: 23.2058 - val_loss: 545.2272 - val_mae: 19.7439
# Epoch 2/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 506.2810 - mae: 18.9509 - val_loss: 210.5482 - val_mae: 12.1643
# Epoch 3/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 151.9461 - mae: 10.2198 - val_loss: 35.2757 - val_mae: 4.7035
# Epoch 4/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29.1494 - mae: 4.2540 - val_loss: 16.9137 - val_mae: 3.0870
# Epoch 5/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 15.0290 - mae: 2.9842 - val_loss: 12.4073 - val_mae: 2.6944
# Epoch 6/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - loss: 11.0612 - mae: 2.5992 - val_loss: 10.6920 - val_mae: 2.5165
# Epoch 7/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - loss: 10.2729 - mae: 2.5653 - val_loss: 9.5055 - val_mae: 2.3780
# Epoch 8/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 8.6268 - mae: 2.3281 - val_loss: 8.2218 - val_mae: 2.2023
# Epoch 9/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.7083 - mae: 2.2168 - val_loss: 7.0003 - val_mae: 2.0280
# Epoch 10/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.2158 - mae: 1.9916 - val_loss: 5.8622 - val_mae: 1.8416
# Epoch 11/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step - loss: 5.3964 - mae: 1.8397 - val_loss: 4.7465 - val_mae: 1.6521
# Epoch 12/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 4.1992 - mae: 1.6149 - val_loss: 3.7482 - val_mae: 1.4598
# Epoch 13/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - loss: 3.2560 - mae: 1.4508 - val_loss: 2.9450 - val_mae: 1.2903
# Epoch 14/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - loss: 2.6324 - mae: 1.2740 - val_loss: 2.2186 - val_mae: 1.1257
# Epoch 15/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - loss: 1.8945 - mae: 1.0846 - val_loss: 1.6958 - val_mae: 0.9881
# Epoch 16/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - loss: 1.4235 - mae: 0.9445 - val_loss: 1.2779 - val_mae: 0.8601
# Epoch 17/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0831 - mae: 0.8249 - val_loss: 0.9659 - val_mae: 0.7489
# Epoch 18/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8232 - mae: 0.7127 - val_loss: 0.7207 - val_mae: 0.6473
# Epoch 19/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 0.5634 - mae: 0.5940 - val_loss: 0.5074 - val_mae: 0.5465
# Epoch 20/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 0.4220 - mae: 0.5094 - val_loss: 0.3715 - val_mae: 0.4597
# Epoch 21/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2745 - mae: 0.4122 - val_loss: 0.2744 - val_mae: 0.3932
# Epoch 22/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - loss: 0.2087 - mae: 0.3560 - val_loss: 0.2087 - val_mae: 0.3425
# Epoch 23/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - loss: 0.1463 - mae: 0.2934 - val_loss: 0.1674 - val_mae: 0.3031
# Epoch 24/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - loss: 0.1097 - mae: 0.2561 - val_loss: 0.1305 - val_mae: 0.2658
# Epoch 25/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 0.
1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - loss: 0.0048 - mae: 0.0500 - val_loss: 0.0095 - val_mae: 0.0583
# Epoch 164/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0032 - mae: 0.0419 - val_loss: 0.0098 - val_mae: 0.0652
# Epoch 165/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 0.0040 - mae: 0.0463 - val_loss: 0.0087 - val_mae: 0.0541
# Epoch 166/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0026 - mae: 0.0387 - val_loss: 0.0089 - val_mae: 0.0614
# Epoch 167/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0055 - mae: 0.0564 - val_loss: 0.0081 - val_mae: 0.0502
# Epoch 168/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0084 - val_mae: 0.0556
# Epoch 169/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0030 - mae: 0.0417 - val_loss: 0.0095 - val_mae: 0.0594
# Epoch 170/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0059 - mae: 0.0598 - val_loss: 0.0100 - val_mae: 0.0624
# Epoch 171/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0040 - mae: 0.0475 - val_loss: 0.0072 - val_mae: 0.0437
# Epoch 172/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 0.0032 - mae: 0.0422 - val_loss: 0.0089 - val_mae: 0.0542
# Epoch 173/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 0.0043 - mae: 0.0454 - val_loss: 0.0107 - val_mae: 0.0623
# Epoch 174/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0031 - mae: 0.0418 - val_loss: 0.0110 - val_mae: 0.0619
# Epoch 175/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0040 - mae: 0.0444 - val_loss: 0.0078 - val_mae: 0.0494
# Epoch 176/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0023 - mae: 0.0366 - val_loss: 0.0080 - val_mae: 0.0531
# Epoch 177/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0030 - mae: 0.0429 - val_loss: 0.0095 - val_mae: 0.0688
# Epoch 178/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0038 - mae: 0.0452 - val_loss: 0.0092 - val_mae: 0.0610
# Epoch 179/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0029 - mae: 0.0400 - val_loss: 0.0094 - val_mae: 0.0611
# Epoch 180/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0034 - mae: 0.0439 - val_loss: 0.0116 - val_mae: 0.0774
# Epoch 181/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0055 - mae: 0.0571 - val_loss: 0.0071 - val_mae: 0.0444
# Epoch 182/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0034 - mae: 0.0433 - val_loss: 0.0096 - val_mae: 0.0646
# Epoch 183/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - loss: 0.0028 - mae: 0.0402 - val_loss: 0.0075 - val_mae: 0.0458
# Epoch 184/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0034 - mae: 0.0397 - val_loss: 0.0073 - val_mae: 0.0493
# Epoch 185/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0040 - mae: 0.0473 - val_loss: 0.0098 - val_mae: 0.0597
# Epoch 186/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0027 - mae: 0.0399 - val_loss: 0.0091 - val_mae: 0.0679
# Epoch 187/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 0.0043 - mae: 0.0503 - val_loss: 0.0085 - val_mae: 0.0611
# Epoch 188/1000
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0039 - mae: 0.0491 - val_loss: 0.0103 - val_mae: 0.0632
# Epoch 189/1000
#  1/64 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0061 - mae: 0.0637
# mae: 0.044324494898319244 < 0.045
#
# val_mae: 0.038872506469488144 < 0.045
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0037 - mae: 0.0482 - val_loss: 0.0067 - val_mae: 0.0389
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - loss: 0.0029 - mae: 0.0358
# Mean Absolute Error on test data: 0.034346576780080795
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#       Actual  Predicted
# 254       25  25.022667
# 3162      40  39.994534
# 969       14  14.038104
# 940       30  29.991659
# 331       10   9.888810

# %%
# Evaluate the model
loss, mae = model.evaluate(X_test, y_test)
print(f'Mean Absolute Error on test data: {mae}')

# Make predictions
y_pred = model.predict(X_test)

# Optional: Convert predictions and actual values to a more readable format
results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred.flatten()})
print(results.head())
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - loss: 0.0029 - mae: 0.0358
# Mean Absolute Error on test data: 0.034346576780080795
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step
#       Actual  Predicted
# 254       25  25.022667
# 3162      40  39.994534
# 969       14  14.038104
# 940       30  29.991659
# 331       10   9.888810
